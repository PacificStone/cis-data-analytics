# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 796  719                Diancie     Rock   Fairy  50     100      150
# 797  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 798  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 799  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 800  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df[df.duplicated(['Name'], keep=False)]
# Out:
#      #   Name  Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 28  23  Ekans  Poison    NaN  35      60       44       40       54     55
# 29  23  Ekans  Poison    NaN  35      60       44       40       54     55
#
#     Generation  Legendary
# 28           1      False
# 29           1      False

# %%
df = df.drop_duplicates(subset=['Name'])
df[df.duplicated(['Name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
grouped = df.groupby(by='Generation').mean().round(2)
sns.relplot(data=grouped, x='Speed', y='Attack', hue='Generation', aspect=1.2, palette='deep')
plt.show()

# %%
sns.barplot(data=df, x='Sp. Atk', y='Type 1', palette='Spectral', ci=None)
plt.show()

# %%
sns.barplot?
