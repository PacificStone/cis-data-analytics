# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Initial upload of csv
# This is where I first uploaded the csv and printed it to make sure that it was successful

# %%
olympics = pd.read_csv('olympics.csv')
olympics.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f1c7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#       <th class="col_heading level0 col10" >10</th>
#       <th class="col_heading level0 col11" >11</th>
#       <th class="col_heading level0 col12" >12</th>
#       <th class="col_heading level0 col13" >13</th>
#       <th class="col_heading level0 col14" >14</th>
#       <th class="col_heading level0 col15" >15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8f1c7_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_8f1c7_row0_col1" class="data row0 col1" >? Summer</td>
#       <td id="T_8f1c7_row0_col2" class="data row0 col2" >01 !</td>
#       <td id="T_8f1c7_row0_col3" class="data row0 col3" >02 !</td>
#       <td id="T_8f1c7_row0_col4" class="data row0 col4" >03 !</td>
#       <td id="T_8f1c7_row0_col5" class="data row0 col5" >Total</td>
#       <td id="T_8f1c7_row0_col6" class="data row0 col6" >? Winter</td>
#       <td id="T_8f1c7_row0_col7" class="data row0 col7" >01 !</td>
#       <td id="T_8f1c7_row0_col8" class="data row0 col8" >02 !</td>
#       <td id="T_8f1c7_row0_col9" class="data row0 col9" >03 !</td>
#       <td id="T_8f1c7_row0_col10" class="data row0 col10" >Total</td>
#       <td id="T_8f1c7_row0_col11" class="data row0 col11" >? Games</td>
#       <td id="T_8f1c7_row0_col12" class="data row0 col12" >01 !</td>
#       <td id="T_8f1c7_row0_col13" class="data row0 col13" >02 !</td>
#       <td id="T_8f1c7_row0_col14" class="data row0 col14" >03 !</td>
#       <td id="T_8f1c7_row0_col15" class="data row0 col15" >Combined total</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row1_col0" class="data row1 col0" >Afghanistan (AFG)</td>
#       <td id="T_8f1c7_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_8f1c7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_8f1c7_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_8f1c7_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_8f1c7_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_8f1c7_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_8f1c7_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_8f1c7_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_8f1c7_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_8f1c7_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_8f1c7_row1_col11" class="data row1 col11" >13</td>
#       <td id="T_8f1c7_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_8f1c7_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_8f1c7_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_8f1c7_row1_col15" class="data row1 col15" >2</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row2_col0" class="data row2 col0" >Algeria (ALG)</td>
#       <td id="T_8f1c7_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_8f1c7_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_8f1c7_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_8f1c7_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_8f1c7_row2_col5" class="data row2 col5" >15</td>
#       <td id="T_8f1c7_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_8f1c7_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_8f1c7_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_8f1c7_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_8f1c7_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_8f1c7_row2_col11" class="data row2 col11" >15</td>
#       <td id="T_8f1c7_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_8f1c7_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_8f1c7_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_8f1c7_row2_col15" class="data row2 col15" >15</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row3_col0" class="data row3 col0" >Argentina (ARG)</td>
#       <td id="T_8f1c7_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_8f1c7_row3_col2" class="data row3 col2" >18</td>
#       <td id="T_8f1c7_row3_col3" class="data row3 col3" >24</td>
#       <td id="T_8f1c7_row3_col4" class="data row3 col4" >28</td>
#       <td id="T_8f1c7_row3_col5" class="data row3 col5" >70</td>
#       <td id="T_8f1c7_row3_col6" class="data row3 col6" >18</td>
#       <td id="T_8f1c7_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_8f1c7_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_8f1c7_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_8f1c7_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_8f1c7_row3_col11" class="data row3 col11" >41</td>
#       <td id="T_8f1c7_row3_col12" class="data row3 col12" >18</td>
#       <td id="T_8f1c7_row3_col13" class="data row3 col13" >24</td>
#       <td id="T_8f1c7_row3_col14" class="data row3 col14" >28</td>
#       <td id="T_8f1c7_row3_col15" class="data row3 col15" >70</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row4_col0" class="data row4 col0" >Armenia (ARM)</td>
#       <td id="T_8f1c7_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_8f1c7_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_8f1c7_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_8f1c7_row4_col4" class="data row4 col4" >9</td>
#       <td id="T_8f1c7_row4_col5" class="data row4 col5" >12</td>
#       <td id="T_8f1c7_row4_col6" class="data row4 col6" >6</td>
#       <td id="T_8f1c7_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_8f1c7_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_8f1c7_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_8f1c7_row4_col10" class="data row4 col10" >0</td>
#       <td id="T_8f1c7_row4_col11" class="data row4 col11" >11</td>
#       <td id="T_8f1c7_row4_col12" class="data row4 col12" >1</td>
#       <td id="T_8f1c7_row4_col13" class="data row4 col13" >2</td>
#       <td id="T_8f1c7_row4_col14" class="data row4 col14" >9</td>
#       <td id="T_8f1c7_row4_col15" class="data row4 col15" >12</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row5_col0" class="data row5 col0" >Australasia (ANZ) [ANZ]</td>
#       <td id="T_8f1c7_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_8f1c7_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_8f1c7_row5_col3" class="data row5 col3" >4</td>
#       <td id="T_8f1c7_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_8f1c7_row5_col5" class="data row5 col5" >12</td>
#       <td id="T_8f1c7_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_8f1c7_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_8f1c7_row5_col8" class="data row5 col8" >0</td>
#       <td id="T_8f1c7_row5_col9" class="data row5 col9" >0</td>
#       <td id="T_8f1c7_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_8f1c7_row5_col11" class="data row5 col11" >2</td>
#       <td id="T_8f1c7_row5_col12" class="data row5 col12" >3</td>
#       <td id="T_8f1c7_row5_col13" class="data row5 col13" >4</td>
#       <td id="T_8f1c7_row5_col14" class="data row5 col14" >5</td>
#       <td id="T_8f1c7_row5_col15" class="data row5 col15" >12</td>
#     </tr>
#     <tr>
#       <td id="T_8f1c7_row6_col0" class="data row6 col0" >Australia (AUS) [AUS] [Z]</td>
#       <td id="T_8f1c7_row6_col1" class="data row6 col1" >25</td>
#       <td id="T_8f1c7_row6_col2" class="data row6 col2" >139</td>
#       <td id="T_8f1c7_row6_col3" class="data row6 col3" >152</td>
#       <td id="T_8f1c7_row6_col4" class="data row6 col4" >177</td>
#       <td id="T_8f1c7_row6_col5" class="data row6 col5" >468</td>
#       <td id="T_8f1c7_row6_col6" class="data row6 col6" >18</td>
#       <td id="T_8f1c7_row6_col7" class="data row6 col7" >5</td>
#       <td id="T_8f1c7_row6_col

# %% [markdown]
# # Change Headers
# The first thing that I notice is that the columns headers are one row below where they need to be. I will change this by setting new_header to the first row and deleting top two rows. Then I will set the columns equal to the first row that I deleted.

# %%
new_header = olympics.iloc[0]
olympics = olympics[1:]
olympics.columns = new_header
olympics
# Out:
# 0                                             NaN ? Summer  01 !  02 !  03 !  \
# 1                               Afghanistan (AFG)       13     0     0     2
# 2                                   Algeria (ALG)       12     5     2     8
# 3                                 Argentina (ARG)       23    18    24    28
# 4                                   Armenia (ARM)        5     1     2     9
# 5                         Australasia (ANZ) [ANZ]        2     3     4     5
# ..                                            ...      ...   ...   ...   ...
# 143  Independent Olympic Participants (IOP) [IOP]        1     0     1     2
# 144                            Zambia (ZAM) [ZAM]       12     0     1     1
# 145                          Zimbabwe (ZIM) [ZIM]       12     3     4     1
# 146                        Mixed team (ZZX) [ZZX]        3     8     5     4
# 147                                        Totals       27  4809  4775  5130
#
# 0    Total ? Winter 01 ! 02 ! 03 ! Total ? Games  01 !  02 !  03 !  \
# 1        2        0    0    0    0     0      13     0     0     2
# 2       15        3    0    0    0     0      15     5     2     8
# 3       70       18    0    0    0     0      41    18    24    28
# 4       12        6    0    0    0     0      11     1     2     9
# 5       12        0    0    0    0     0       2     3     4     5
# ..     ...      ...  ...  ...  ...   ...     ...   ...   ...   ...
# 143      3        0    0    0    0     0       1     0     1     2
# 144      2        0    0    0    0     0      12     0     1     1
# 145      8        1    0    0    0     0      13     3     4     1
# 146     17        0    0    0    0     0       3     8     5     4
# 147  14714       22  959  958  948  2865      49  5768  5733  6078
#
# 0   Combined total
# 1                2
# 2               15
# 3               70
# 4               12
# 5               12
# ..             ...
# 143              3
# 144              2
# 145              8
# 146             17
# 147          17579
#
# [147 rows x 16 columns]

# %% [markdown]
# # Fix Header
# Next I notice that the headers are not very descriptive or missing values so I will replace them While turning the columns into a multi-index for greater context.

# %%
multi_tuple = [('Country', 'Name'),
               ('Summer', 'Games Participated'),
               ('Summer', 'Gold'),
               ('Summer', 'Silver'),
               ('Summer', 'Bronze'),
               ('Summer', 'Total'),
               ('Winter', 'Games Participated'),
               ('Winter', 'Gold'),
               ('Winter', 'Silver'),
               ('Winter', 'Bronze'),
               ('Winter', 'Total'),
               ('Total', 'Games Participated'),
               ('Total', 'Gold'),
               ('Total', 'Silver'),
               ('Total', 'Bronze'),
               ('Total', 'Total Medals')]

olympics.columns = pd.MultiIndex.from_tuples(multi_tuple)

olympics
# Out:
#                                           Country             Summer        \
#                                              Name Games Participated  Gold
# 1                               Afghanistan (AFG)                 13     0
# 2                                   Algeria (ALG)                 12     5
# 3                                 Argentina (ARG)                 23    18
# 4                                   Armenia (ARM)                  5     1
# 5                         Australasia (ANZ) [ANZ]                  2     3
# ..                                            ...                ...   ...
# 143  Independent Olympic Participants (IOP) [IOP]                  1     0
# 144                            Zambia (ZAM) [ZAM]                 12     0
# 145                          Zimbabwe (ZIM) [ZIM]                 12     3
# 146                        Mixed team (ZZX) [ZZX]                  3     8
# 147                                        Totals                 27  4809
#
#                                      Winter                           \
#     Silver Bronze  Total Games Participated Gold Silver Bronze Total
# 1        0      2      2                  0    0      0      0     0
# 2        2      8     15                  3    0      0      0     0
# 3       24     28     70                 18    0      0      0     0
# 4        2      9     12                  6    0      0      0     0
# 5        4      5     12                  0    0      0      0     0
# ..     ...    ...    ...                ...  ...    ...    ...   ...
# 143      1      2      3                  0    0      0      0     0
# 144      1      1      2                  0    0      0      0     0
# 145      4      1      8                  1    0      0      0     0
# 146      5      4     17                  0    0      0      0     0
# 147   4775   5130  14714                 22  959    958    948  2865
#
#                  Total
#     Games Participated  Gold Silver Bronze Total Medals
# 1                   13     0      0      2            2
# 2                   15     5      2      8           15
# 3                   41    18     24     28           70
# 4                   11     1      2      9           12
# 5                    2     3      4      5           12
# ..                 ...   ...    ...    ...          ...
# 143                  1     0      1      2            3
# 144                 12     0      1      1            2
# 145                 13     3      4      1            8
# 146                  3     8      5      4           17
# 147                 49  5768   5733   6078        17579
#
# [147 rows x 16 columns]

# %% [markdown]
# # Check Duplicates
# I will run a check for duplicates and print a chart of any duplicates that I find

# %%
duplicates = olympics[olympics.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [(Country, Name), (Summer, Games Participated), (Summer, Gold), (Summer, Silver), (Summer, Bronze), (Summer, Total), (Winter, Games Participated), (Winter, Gold), (Winter, Silver), (Winter, Bronze), (Winter, Total), (Total, Games Participated), (Total, Gold), (Total, Silver), (Total, Bronze), (Total, Total Medals)]
# Index: []

# %% [markdown]
# # Re-sort based on Country Name
# No duplicates found. Now I notice that the table is sorted by the countries symbol and not there name. For example, Chinese Tapei is found in the T's and the International olympic committee is with the Z's. I will fix this by resorting these columns according to their countries names.

# %%
df1 = olympics[olympics[('Country','Name')]!='Totals'].sort_values(by=('Country','Name'))
df1 = df1.append(olympics[olympics[('Country','Name')]=='Totals'])
olympics = df1
olympics
# Out:
#                       Country             Summer                             \
#                          Name Games Participated  Gold Silver Bronze  Total
# 1           Afghanistan (AFG)                 13     0      0      2      2
# 2               Algeria (ALG)                 12     5      2      8     15
# 3             Argentina (ARG)                 23    18     24     28     70
# 4               Armenia (ARM)                  5     1      2      9     12
# 5     Australasia (ANZ) [ANZ]                  2     3      4      5     12
# ..                        ...                ...   ...    ...    ...    ...
# 48   West Germany (FRG) [FRG]                  5    56     67     81    204
# 142    Yugoslavia (YUG) [YUG]                 16    26     29     28     83
# 144        Zambia (ZAM) [ZAM]                 12     0      1      1      2
# 145      Zimbabwe (ZIM) [ZIM]                 12     3      4      1      8
# 147                    Totals                 27  4809   4775   5130  14714
#
#                 Winter                                       Total        \
#     Games Participated Gold Silver Bronze Total Games Participated  Gold
# 1                    0    0      0      0     0                 13     0
# 2                    3    0      0      0     0                 15     5
# 3                   18    0      0      0     0                 41    18
# 4                    6    0      0      0     0                 11     1
# 5                    0    0      0      0     0                  2     3
# ..                 ...  ...    ...    ...   ...                ...   ...
# 48                   6   11     15     13    39                 11    67
# 142                 14    0      3      1     4                 30    26
# 144                  0    0      0      0     0                 12     0
# 145                  1    0      0      0     0                 13     3
# 147                 22  959    958    948  2865                 49  5768
#
#
#     Silver Bronze Total Medals
# 1        0      2            2
# 2        2      8           15
# 3       24     28           70
# 4        2      9           12
# 5        4      5           12
# ..     ...    ...          ...
# 48      82     94          243
# 142     32     29           87
# 144      1      1            2
# 145      4      1            8
# 147   5733   6078        17579
#
# [147 rows x 16 columns]

# %% [markdown]
# # Fix country abbreviation and create column for it
# I noticed that the abbreviations for the countries are clunky and some of them have multiple abbreviations. It seems that the first one is right so I will change it so that there is a seperate column for abbreviations and then make it so it only shows the first abbreviation.

# %%
names_list = olympics[('Country', 'Name')]
names_list = names_list.str.split("(")
names_list = names_list.tolist()
nested_list = names_list[146]
nested_list.append('')

country_names_list = []
countryabbr = []

for i in range(len(names_list)):
    country_names_list.append(names_list[i][0])
    countryabbr.append(names_list[i][1])

olympics[('Country', 'Name')] = country_names_list
olympics[('Country', 'Abbreviation')] = countryabbr

abbr_list = olympics[('Country', 'Abbreviation')]
abbr_list = abbr_list.str.split(")")
abbr_list = abbr_list.tolist()

abbr_final = []

for i in range(len(abbr_list)):
    abbr_final.append(abbr_list[i][0])
               
olympics[('Country', 'Abbreviation')] = abbr_final

# Changing the order of the columns to be clearer
olympics = olympics.sort_index(axis=1, level=0, sort_remaining=False)
olympics = olympics[['Country', 'Summer', 'Winter', 'Total']]

# %% [markdown]
# # Final Result

# %%
olympics = olympics.style.set_properties(**{'text-align': 'left'})
olympics = olympics.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])